# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
# Baca gambar
image = cv2.imread('foto orang.jpg')

# %%
# Thresholding
threshold_value = 50
maximum_value = 900
_, thresholded_image = cv2.threshold(image, threshold_value, maximum_value, cv2.THRESH_BINARY)

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=640x427>

# %%
# Tampilkan gambar yang telah di ubah
plt.subplot(1, 2, 2)
plt.imshow(thresholded_image)
plt.title('Thresholded Image')

plt.show()
